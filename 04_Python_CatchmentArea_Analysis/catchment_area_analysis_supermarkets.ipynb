# %% [markdown]
# # Catchment area analysis of supermarkets

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import time
import glob
import json
import folium
import requests
import platform
import numpy as np
import pandas as pd
import geopandas as gdp
import matplotlib.pyplot as plt
from openrouteservice import client
from IPython.display import clear_output

# Read OpenRouteService API key
with open(file='ors_token.txt', mode='r') as file:
    api_key = file.read()
# print(api_key)

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Create isochrone for a defined location

# %%
# Client settings
ors = client.Client(key=api_key)

# Settings
transport = 'driving-car'  # 'driving-car', 'foot-walking', 'cycling-regular'
traveltime = 15  # in minutes

# Location (lat, lon)
location = (47.37445, 8.54104)

# Parameters for server-request
params_iso = {
    'locations': [(location[1], location[0])],  # (lon, lat)
    'profile': transport,
    'range': [traveltime * 60],  # in seconds
    'attributes': ['total_pop']
}

# Server request
isochrone = ors.isochrones(**params_iso)

# Set up folium map
map = folium.Map(tiles='openstreetmap', 
                 location=location, 
                 zoom_start=11)

# Add isochrone to the map
folium.GeoJson(isochrone).add_to(map)

# Display the map in a Jupyter Notebook (if applicable)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d042bf30c0d5514e48cbb8dd88ebbd3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d042bf30c0d5514e48cbb8dd88ebbd3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d042bf30c0d5514e48cbb8dd88ebbd3 = L.map(
#                 &quot;map_0d042bf30c0d5514e48cbb8dd88ebbd3&quot;,
#                 {
#                     center: [47.37445, 8.54104],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c512786b6e0a98d1dc3d9221598d8db0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c512786b6e0a98d1dc3d9221598d8db0.addTo(map_0d042bf30c0d5514e48cbb8dd88ebbd3);
#
#
#
#         function geo_json_782373a54e920c00e696186860126df4_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_782373a54e920c00e696186860126df4 = L.geoJson(null, {
#                 onEachFeature: geo_json_782373a54e920c00e696186860126df4_onEachFeature,
#
#         });
#
#         function geo_json_782373a54e920c00e696186860126df4_add (data) {
#             geo_json_782373a54e920c00e696186860126df4
#                 .addData(data);
#         }
#             geo_json_782373a54e920c00e696186860126df4_add({&quot;bbox&quot;: [8.420168, 47.252524, 8.69079, 47.494952], &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.420371, 47.357694], [8.420251, 47.357067], [8.420168, 47.356177], [8.420174, 47.355447], [8.420218, 47.354808], [8.42031, 47.354251], [8.420574, 47.353285], [8.420812, 47.352661], [8.421186, 47.351861], [8.424343, 47.34548], [8.431262, 47.341798], [8.431666, 47.341533], [8.432095, 47.341276], [8.432902, 47.340835], [8.433804, 47.340414], [8.4347, 47.340043], [8.435754, 47.339688], [8.436783, 47.339396], [8.437449, 47.339242], [8.438099, 47.339115], [8.438753, 47.339008], [8.439386, 47.338913], [8.440504, 47.338813], [8.441638, 47.33876], [8.442489, 47.33876], [8.443342, 47.338794], [8.44436, 47.338875], [8.450355, 47.336727], [8.450954, 47.327798], [8.448328, 47.324968], [8.445702, 47.322138], [8.443374, 47.31963], [8.441047, 47.317122], [8.443686, 47.314673], [8.446013, 47.317181], [8.448341, 47.319689], [8.450967, 47.322519], [8.453593, 47.325349], [8.456219, 47.328179], [8.458845, 47.331008], [8.459967, 47.332327], [8.460382, 47.332918], [8.461018, 47.33407], [8.460912, 47.335034], [8.462377, 47.342389], [8.464433, 47.345344], [8.470641, 47.348269], [8.471209, 47.348317], [8.471763, 47.348341], [8.472363, 47.348348], [8.472947, 47.348335], [8.
# 7    39947904  47.376732  8.542161    Coop         261   Zürich
#
#   addr:housenumber  addr:postcode                      geometry
# 1                3         8718.0  POINT (9.0396663 47.1554921)
# 2               14         8718.0  POINT (9.0444769 47.1589589)
# 4               25         8730.0  POINT (8.9803292 47.2261912)
# 6               15         8730.0  POINT (8.9706499 47.2250563)
# 7                1         8001.0  POINT (8.5421608 47.3767316)

# %% [markdown]
# ## Create isochrone for a single supermarket

# %%
# Settings
municip = 'Wädenswil'
transport = 'cycling-regular'  # 'driving-car', 'foot-walking', 'cycling-regular'
traveltime = 10

# Client settings
ors = client.Client(key=api_key)

# Set up supermarket dictionary with a single supermarket
df_sub = df.loc[df['bfs_name'] == municip].iloc[0]
supermarkets = {df_sub['brand']: {'location': [df_sub['lon'], 
                                               df_sub['lat']]}}
print(supermarkets)

# Set up folium map
map = folium.Map(tiles='openstreetmap', 
                 location=([df_sub['lat'], 
                            df_sub['lon']]), 
                 zoom_start=11)

# Parameters for server-request
params_iso = {'profile': transport,
              'range': [traveltime*60],
              'attributes': ['total_pop']}

# Server request
for name, apt in supermarkets.items():
    
    # Add coords to request parameters
    params_iso['locations'] = [apt['location']]
    
    # Perform isochrone request
    apt['iso'] = ors.isochrones(**params_iso)
    
    # Add GeoJson to map
    folium.features.GeoJson(apt['iso']).add_to(map)
    
    # Save GeoJson as file
    # with open(f'{name}.json', 'w') as f:
        # f.write(json.dumps(apt['iso']))

    # Reverse coords due to weird folium lat/lon syntax
    folium.map.Marker(list(reversed(apt['location'])),
                      icon = folium.Icon(color='green',
                                         icon_color='#cc0000',
                                         icon='home',
                                         prefix="fa"),
                      popup = name
                      ).add_to(map)

# Plot map
map
# Out:
# {'Coop': {'location': [np.float64(8.6725008), np.float64(47.2300812)]}}
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d3bccd02102253f2fef859cdfe6161a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d3bccd02102253f2fef859cdfe6161a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d3bccd02102253f2fef859cdfe6161a = L.map(
#                 &quot;map_7d3bccd02102253f2fef859cdfe6161a&quot;,
#                 {
#                     center: [47.2300812, 8.6725008],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db7373ef7e17ad60cc44e87e96faac4e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_db7373ef7e17ad60cc44e87e96faac4e.addTo(map_7d3bccd02102253f2fef859cdfe6161a);
#
#
#
#         function geo_json_d7251dff2d361a3cd0c40aeec8f3f320_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d7251dff2d361a3cd0c40aeec8f3f320 = L.geoJson(null, {
#                 onEachFeature: geo_json_d7251dff2d361a3cd0c40aeec8f3f320_onEachFeature,
#
#         });
#
#         function geo_json_d7251dff2d361a3cd0c40aeec8f3f320_add (data) {
#             geo_json_d7251dff2d361a3cd0c40aeec8f3f320
#                 .addData(data);
#         }
#             geo_json_d7251dff2d361a3cd0c40aeec8f3f320_add({&quot;bbox&quot;: [8.636616, 47.207067, 8.703124, 47.250294], &quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.638399, 47.235924], [8.638664, 47.228055], [8.639227, 47.226285], [8.641774, 47.221754], [8.646383, 47.216947], [8.651497, 47.214574], [8.659252, 47.213915], [8.664449, 47.210813], [8.667623, 47.209114], [8.669129, 47.209024], [8.677306, 47.207782], [8.683204, 47.207067], [8.684467, 47.20717], [8.685953, 47.208766], [8.689778, 47.211275], [8.696249, 47.212892], [8.699546, 47.211881], [8.70033, 47.211769], [8.700682, 47.211835], [8.701839, 47.21308], [8.702906, 47.214736], [8.703124, 47.215121], [8.702825, 47.215636], [8.702191, 47.216676], [8.702141, 47.216744], [8.69789, 47.223516], [8.695466, 47.224711], [8.696585, 47.232471], [8.700156, 47.23316], [8.699473, 47.236695], [8.695903, 47.236006], [8.692333, 47.235316], [8.688039, 47.234488], [8.683484, 47.240069], [8.68544, 47.243338], [8.682351, 47.245186], [8.680395, 47.241918], [8.671932, 47.241433], [8.670361, 47.24323], [8.668919, 47.244399], [8.667478, 47.245568], [8.659101, 47.243892], [8.658364, 47.244503], [8.657695, 47.244927], [8.653709, 47.249163], [8.653108, 47.250074], [8.652971, 47.250186], [8.651579, 47.250294], [8.649349, 47.249675], [8.646061, 47.248702], [8.644022, 47.247354], [8.642528, 47.245052], [8.63669, 47.239176], [8.636616, 47.239051], [8.638399, 47.235924]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;center&quot;: [8.672371360008519, 47.23001911603166], &quot;group_index&quot;: 0, &quot;total_pop&quot;: 21166.0, &quot;value&quot;: 600.0}, &quot;type&quot;: &quot;Feature&quot;}], &quot;metadata&quot;: {&quot;attribution&quot;: &quot;openrouteservice.org | OpenStreetMap contributors&quot;, &quot;engine&quot;: {&quot;build_date&quot;: &quot;2024-10-09T09:23:42Z&quot;, &quot;graph_date&quot;: &quot;2024-09-17T19:09:02Z&quot;, &quot;version&quot;: &quot;8.2.0&quot;}, &quot;query&quot;: {&quot;attributes&quot;: [&quot;total_pop&quot;], &quot;locations&quot;: [[8.6725008, 47.2300812]], &quot;profile&quot;: &quot;cycling-regular&quot;, &quot;range&quot;: [600.0], &quot;range_type&quot;: &quot;time&quot;}, &quot;service&quot;: &quot;isochrones&quot;, &quot;timestamp&quot;: 1732970604464}, &quot;type&quot;: &quot;FeatureCollection&quot;});
#         geo_json_d7251dff2d361a3cd0c40aeec8f3f320.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_d7251dff2d361a3cd0c40aeec8f3f320.addTo(map_7d3bccd02102253f2fef859cdfe6161a);
#
#
#             var marker_ad1d906249f8b52f4452ed0d0f122898 = L.marker(
#                 [47.2300812, 8.6725008],
#                 {}
#             ).addTo(map_7d3bccd02102253f2fef859cdfe6161a);
#
#
#             var icon_3ae4953776b7f4a25d3cdd793b9c4915 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;#cc0000&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ad1d906249f8b52f4452ed0d0f122898.setIcon(icon_3ae4953776b7f4a25d3cdd793b9c4915);
#
#
#         var popup_b5308df176126ce930422d3a0afb1695 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a68b4af02528b8c87aec5a54dd94d1d1 = $(`&lt;div id=&quot;html_a68b4af02528b8c87aec5a54dd94d1d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_b5308df176126ce930422d3a0afb1695.setContent(html

# %% [markdown]
# ## Getting the number of residents in the isochrone area

# %%
# Save the data as pandas data frame
data = pd.DataFrame(apt['iso']["features"])

# Create data frame from column 'properties'
df_pop = pd.DataFrame(data.loc[0, 'properties'])
val = df_pop['total_pop'][0]
print('Number of residents in isochrone area:', f'{val:,.0f}')
# Out:
# Number of residents in isochrone area: 21,166

# %% [markdown]
# ## Estimating the purchasing power in the isochrone area

# %%
# Simple assumtions:
# 500 CHF per resident and month
# Residents / employee ratio = 2:1
# 20 CHF per employee and working day

# Result
val = ((df_pop['total_pop'][0] * 500) + (df_pop['total_pop'][0] * 0.5 * 20 * 20)) / 10**6
print('Purchasing power per month:',
      f'{val:.1f}',
     'Mio. CHF')
# Out:
# Purchasing power per month: 14.8 Mio. CHF

# %% [markdown]
# ## Automization of the analysis for multiple of supermarkets

# %%
# Client settings
ors = client.Client(key=api_key)

# Parameters for server-request
params_iso = {'profile': 'driving-car',
              'range': [15*60],
              'attributes': ['total_pop']}

# Df to store the data
pop_out = []

try:
    for i in range(0, 10):
        
        print('Preparing isochrone for supermarkt', df[['id', 
                                                        'brand', 
                                                        'bfs_name', 
                                                        'addr:housenumber',
                                                        'addr:postcode']].iloc[i])
        
        supermarkets = {df['brand'].iloc[i]: {'location': [df['lon'].iloc[i],
                                                           df['lat'].iloc[i]]}}
        # Server request
        for name, apt in supermarkets.items():
            
            # Add coords to request parameters
            params_iso['locations'] = [apt['location']]
            
            # Perform isochrone request
            apt['iso'] = ors.isochrones(**params_iso)
            time.sleep(1)
            
            # Save the data as pandas data frame
            data = pd.DataFrame(apt['iso']["features"])
            
            # Create data frame from column 'properties'
            df_pop = pd.DataFrame(data.loc[0, 'properties'])
            
            # Write values
            pop_out.append([df['id'].iloc[i], 
                            df['brand'].iloc[i],
                            df['bfs_number'].iloc[i], 
                            df['bfs_name'].iloc[i], 
                            df['addr:housenumber'].iloc[i],
                            df['addr:postcode'].iloc[i],
                            df_pop['total_pop'][0],
                            ((df_pop['total_pop'][0] * 500) + (df_pop['total_pop'][0] * 0.5 * 20 * 20)) / 10**6])
            clear_output(wait=True)
            
except:
    pop_out.append([df['id'].iloc[i], 
                    df['brand'].iloc[i],
                    df['bfs_number'].iloc[i], 
                    df['bfs_name'].iloc[i], 
                    df['addr:housenumber'].iloc[i],
                    df['addr:postcode'].iloc[i],
                    np.NaN,
                    np.NaN])
    clear_output(wait=True)

# Convert the list to a DataFrame
columns = ['id', 'brand', 'bfs_number', 'bfs_name', 'addr:housenumber', 'addr:postcode', 'total_pop', 'purchasing_power']
df_result = pd.DataFrame(pop_out, columns=columns)

# Display the DataFrame
df_result
# Out:
#            id   brand  bfs_number bfs_name addr:housenumber  addr:postcode  \
# 0   280130028    ALDI        3315  Schänis                3         8718.0
# 1  6122906632  Denner        3315  Schänis               14         8718.0
# 2    36726161  Migros        3339   Uznach               25         8730.0
# 3  7389830915  Denner        3339   Uznach               15         8730.0
# 4    39947904    Coop         261   Zürich                1         8001.0
# 5    48932835  Migros         261   Zürich                7         8004.0
# 6    75749133    ALDI         261   Zürich               81         8038.0
# 7    79977755    Coop         261   Zürich               15         8038.0
# 8    83330862  Migros         261   Zürich                3         8038.0
# 9   119249170  Migros         261   Zürich            31-35         8001.0
#
#    total_pop  purchasing_power
# 0    75965.0           53.1755
# 1    74600.0           52.2200
# 2    61083.0           42.7581
# 3    59375.0           41.5625
# 4   491567.0          344.0969
# 5   489171.0          342.4197
# 6   317426.0          222.1982
# 7   308978.0          216.2846
# 8   313760.0          219.6320
# 9   484612.0          339.2284

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-11-30 12:37:48
# Python Version: 3.11.10
# -----------------------------------
