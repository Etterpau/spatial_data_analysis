# %% [markdown]
# # Preparation of GWR - Data

# %% [markdown]
# ## Libraries and Settings

# %%
# Libraries
import os
import json
import folium
import requests
import numpy as np
import pandas as pd
import geopandas as gpd
from datetime import date

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print(os.getcwd())
# Out:
# /workspaces/spatial_data_analysis/05_Python_GWR_Data

# %% [markdown]
# ## Download GWR data
#
# Source: https://public.madd.bfs.admin.ch

# %%
# Download latest file for the Canton of Zurich
url = "https://public.madd.bfs.admin.ch/buildings_zh.geojson" #when i want more data i just need to change the url
response = requests.get(url)

# Ensure response is valid
if response.status_code == 200:
    # Open file in write mode and write the response content
    with open('buildings_zh.geojson', 'wb') as file:
        file.write(response.content)
else:
    print(f"Failed to download file, status code: {response.status_code}")

# %% [markdown]
# ## Import latest GWR Data

# %%
# Load json file
with open('buildings_zh.geojson') as f:
    data = json.load(f)

# Flatten nested json data
df_orig = pd.json_normalize(data, record_path=['features'])
df_orig

# Remove prefix
df_orig.columns = df_orig.columns.str.replace('properties.', '')
df_orig.columns = df_orig.columns.str.replace('geometry.', '')

# Create copy
df = df_orig.copy()
df.head()
# Out:
#       type   egid  buildingStatus  buildingCategory  buildingClass  \
# 0  Feature      1            1004              1040           1271
# 1  Feature     10            1004              1020           1110
# 2  Feature    100            1004              1020           1110
# 3  Feature   1000            1007              1030           1110
# 4  Feature  10000            1004              1030           1121
#
#    municipalityNumber    municipalityName canton   type  \
# 0                   2  Affoltern am Albis     ZH  Point
# 1                   2  Affoltern am Albis     ZH  Point
# 2                   2  Affoltern am Albis     ZH  Point
# 3                   2  Affoltern am Albis     ZH  Point
# 4                 291         Andelfingen     ZH  Point
#
#                   coordinates
# 0          [2676523, 1235843]
# 1  [2676440.038, 1235973.538]
# 2  [2676765.706, 1236101.658]
# 3  [2676644.881, 1236812.863]
# 4   [2693391.65, 1272255.267]

# %% [markdown]
# ## Separate Swiss LV95 coordinates

# %%
# Separate coordinates
df['x_coords'] = pd.DataFrame(df['coordinates'].tolist(), columns=['x_coord', 'y_coord'])['x_coord']
df['y_coords'] = pd.DataFrame(df['coordinates'].tolist(), columns=['x_coord', 'y_coord'])['y_coord']

# Remove column 'coordinates'
df = df.drop(['coordinates'], axis=1)
df
# Out:
#            type   egid  buildingStatus  buildingCategory  buildingClass  \
# 0       Feature      1            1004              1040           1271
# 1       Feature     10            1004              1020           1110
# 2       Feature    100            1004              1020           1110
# 3       Feature   1000            1007              1030           1110
# 4       Feature  10000            1004              1030           1121
# ...         ...    ...             ...               ...            ...
# 395118  Feature  99995            1004              1040              0
# 395119  Feature  99996            1004              1040              0
# 395120  Feature  99997            1004              1040              0
# 395121  Feature  99998            1004              1040              0
# 395122  Feature  99999            1007              1040              0
#
#         municipalityNumber    municipalityName canton   type     x_coords  \
# 0                        2  Affoltern am Albis     ZH  Point  2676523.000
# 1                        2  Affoltern am Albis     ZH  Point  2676440.038
# 2                        2  Affoltern am Albis     ZH  Point  2676765.706
# 3                        2  Affoltern am Albis     ZH  Point  2676644.881
# 4                      291         Andelfingen     ZH  Point  2693391.650
# ...                    ...                 ...    ...    ...          ...
# 395118                 198               Uster     ZH  Point  2696792.976
# 395119                 198               Uster     ZH  Point  2696718.474
# 395120                 198               Uster     ZH  Point  2696722.040
# 395121                 198               Uster     ZH  Point  2696727.666
# 395122                 198               Uster     ZH  Point  2696710.888
#
#            y_coords
# 0       1235843.000
# 1       1235973.538
# 2       1236101.658
# 3       1236812.863
# 4       1272255.267
# ...             ...
# 395118  1245085.637
# 395119  1245039.536
# 395120  1245043.472
# 395121  1245050.586
# 395122  1245059.793
#
# [395123 rows x 11 columns]

# %% [markdown]
# ## Create WGS84 coordinates

# %%
# Create geodataframe and calculate latitude and longitude
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['x_coords'], df['y_coords']), crs="EPSG:2056")

# Convert the Swiss LV95 coordinates to lat & lon
gdf = gdf.to_crs(epsg=4326)

# Get Latitude and Longitude
df['latitude'] = gdf['geometry'].y
df['longitude'] = gdf['geometry'].x

# Show data
df
# Out:
#            type   egid  buildingStatus  buildingCategory  buildingClass  \
# 0       Feature      1            1004              1040           1271
# 1       Feature     10            1004              1020           1110
# 2       Feature    100            1004              1020           1110
# 3       Feature   1000            1007              1030           1110
# 4       Feature  10000            1004              1030           1121
# ...         ...    ...             ...               ...            ...
# 395118  Feature  99995            1004              1040              0
# 395119  Feature  99996            1004              1040              0
# 395120  Feature  99997            1004              1040              0
# 395121  Feature  99998            1004              1040              0
# 395122  Feature  99999            1007              1040              0
#
#         municipalityNumber    municipalityName canton   type     x_coords  \
# 0                        2  Affoltern am Albis     ZH  Point  2676523.000
# 1                        2  Affoltern am Albis     ZH  Point  2676440.038
# 2                        2  Affoltern am Albis     ZH  Point  2676765.706
# 3                        2  Affoltern am Albis     ZH  Point  2676644.881
# 4                      291         Andelfingen     ZH  Point  2693391.650
# ...                    ...                 ...    ...    ...          ...
# 395118                 198               Uster     ZH  Point  2696792.976
# 395119                 198               Uster     ZH  Point  2696718.474
# 395120                 198               Uster     ZH  Point  2696722.040
# 395121                 198               Uster     ZH  Point  2696727.666
# 395122                 198               Uster     ZH  Point  2696710.888
#
#            y_coords   latitude  longitude
# 0       1235843.000  47.269056   8.449859
# 1       1235973.538  47.270239   8.448785
# 2       1236101.658  47.271354   8.453110
# 3       1236812.863  47.277764   8.451635
# 4       1272255.267  47.594339   8.680355
# ...             ...        ...        ...
# 395118  1245085.637  47.349516   8.719673
# 395119  1245039.536  47.349113   8.718677
# 395120  1245043.472  47.349147   8.718725
# 395121  1245050.586  47.349211   8.718801
# 395122  1245059.793  47.349296   8.718581
#
# [395123 rows x 13 columns]

# %% [markdown]
# ## Match descriptions to buildingCategory &	buildingClass

# %%
# Read .xslx file with the data
df_gwr_cat = pd.read_excel('gkat_translator.xlsx', sheet_name='buildingCategory')
df_gwr_class = pd.read_excel('gkat_translator.xlsx', sheet_name='buildingClass')

# Merge the DataFrames on 'buildingCategory'
df_merged = pd.merge(df, df_gwr_cat, on='buildingCategory', how='left')
df_merged = pd.merge(df_merged, df_gwr_class, on='buildingClass', how='left')

# Show data
df_merged[['egid', 'buildingCategory', 'buildingClass', 'buildingCategoryDesc', 'buildingClassDesc']].head()
# Out:
#     egid  buildingCategory  buildingClass  \
# 0      1              1040           1271
# 1     10              1020           1110
# 2    100              1020           1110
# 3   1000              1030           1110
# 4  10000              1030           1121
#
#                         buildingCategoryDesc  \
# 0        Gebäude mit teilweiser Wohnnutzung
# 1  Gebäude mit ausschliesslicher Wohnnutzung
# 2  Gebäude mit ausschliesslicher Wohnnutzung
# 3               Wohngebäude mit Nebennutzung
# 4               Wohngebäude mit Nebennutzung
#
#                      buildingClassDesc
# 0  Landwirtschaftliche Betriebsgebäude
# 1            Gebäude mit einer Wohnung
# 2            Gebäude mit einer Wohnung
# 3            Gebäude mit einer Wohnung
# 4           Gebäude mit zwei Wohnungen

# %% [markdown]
# ## Plot subset of buildings

# %%
# Subset
df_sub = df_merged.loc[df['municipalityName'] == 'Greifensee'].sample(100).dropna()

# Create the map
m = folium.Map(location=[df_sub['latitude'].mean(), df_sub['longitude'].mean()], zoom_start=15)

# Add points to the map
for idx, row in df_sub.iterrows():
    folium.Marker(location=([row['latitude'], 
                            row['longitude']]),
                  popup=row['buildingClassDesc']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd775a7c42a4eec83dab9c643f4460bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd775a7c42a4eec83dab9c643f4460bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd775a7c42a4eec83dab9c643f4460bc = L.map(
#                 &quot;map_fd775a7c42a4eec83dab9c643f4460bc&quot;,
#                 {
#                     center: [47.366501564267544, 8.681567197202142],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_135d8a21d605a02e82bd93bfb0487043 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_135d8a21d605a02e82bd93bfb0487043.addTo(map_fd775a7c42a4eec83dab9c643f4460bc);
#
#
#             var marker_d90a4ccddbd670960a77bd575d9f71e4 = L.marker(
#                 [47.36911783803705, 8.679948645817507],
#                 {}
#             ).addTo(map_fd775a7c42a4eec83dab9c643f4460bc);
#
#
#         var popup_a67deb3695abb66a583555e85103eeea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b5b794ef6b5fe545e15ef319c64d747 = $(`&lt;div id=&quot;html_5b5b794ef6b5fe545e15ef319c64d747&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gebäude mit drei oder mehr Wohnungen&lt;/div&gt;`)[0];
#                 popup_a67deb3695abb66a583555e85103eeea.setContent(html_5b5b794ef6b5fe545e15ef319c64d747);
#
#
#
#         marker_d90a4ccddbd670960a77bd575d9f71e4.bindPopup(popup_a67deb3695abb66a583555e85103eeea)
#         ;
#
#
#
#
#             var marker_1c6e9adc05c708dacccc95497df54fd2 = L.marker(
#                 [47.36624958762349, 8.681334958293451],
#                 {}
#             ).addTo(map_fd775a7c42a4eec83dab9c643f4460bc);
#
#
#         var popup_aab21ac2942067b8fc3ca32bdb1137a3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d85e8d836a9e05c03f72003fbb0523f1 = $(`&lt;div id=&quot;html_d85e8d836a9e05c03f72003fbb0523f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gebäude mit einer Wohnung&lt;/div&gt;`)[0];
#                 popup_aab21ac2942067b8fc3ca32bdb1137a3.setContent(html_d85e8d836a9e05c03f72003fbb0523f1);
#
#
#
#         marker_1c6e9adc05c708dacccc95497df54fd2.bindPopup(popup_aab21ac2942067b8fc3ca32bdb1137a3)
#         ;
#
#
#
#
#             var marker_3062256186a57750ac7d4d303996250f = L.marker(
#                 [47.370143254914396, 8.678272394387584],
#                 {}
#             ).addTo(map_fd775a7c42a4eec83dab9c643f4460bc);
#
#
#         var popup_8f314d08e6b38e405a53138241408ad1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2f6c6644914a6093bda32d91318093fe = $(`&lt;div id=&quot;html_2f6c6644914a6093bda32d91318093fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Garagengebäude&lt;/div&gt;`)[0];
#                 popup_8f314d08e6b38e405a53138241408ad1.setContent(html_2f6c6644914a6093bda32d91318093fe);
#
#
#
#         marker_3062256186a57750ac7d4d303996250f.bindPopup(popup_8f314d08e6b38e405a53138241408ad1)
#         ;
#
#
#
#
#             var marker_0f87f1b9efd218f816a917a11b89f1a6 = L.marker(
#                 [47.359954520708854, 8.691472556896747],
#                 {}
#             ).addTo(map_fd775a7c42a4eec83dab9c643f4460bc);
#
#
#         var popup_33f60bcb2a41f8f88cc0ca44f627c077 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9274985f0a5385027542bca15948da3a = $(`&lt;div id=&quot;html_9274985f0a5385027542bca15948da3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gebäude mit einer Wohnung&lt;/div&gt;`)[0];
#                 popup_33f60bcb2a41f8f88cc0ca44f627c077.setContent(html_9274985f0a5385027542bca15948da3a);
#
#
#
#         marker_0f87f1b9efd218f816a917a11b89f1a6.bindPopup(popup_33f60bcb2a41f8f88cc0ca44f627c077)
#         ;
#
#
#
#
#             var marker_f7b90f7b8c6793f51e76f486656d6686 = L.marker(
#                 [47.35880412301058, 8.691071023124787],
#                 {}
#             ).addTo(map_fd775a7c42a4eec83dab9c643f4460bc);
#
#
#         var popup_05fdbfd1e4d9d556a6865c4bace0141e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37640cdc66f4eb5726d676afcd9e651d = $(`&lt;div id=&quot;html_37640cdc66f4eb5726d676afcd9e651d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sonstige Hochbauten anderweitig nicht genannt&lt;/div&gt;`)[0];
#                 popup_05fdbfd1e4d9d556a6865c4bace0141e.setContent(html_37640cdc66f4eb5726d676afcd9e651d);
#
#
#
#         marker_f7b90f7b8c6793f51e76f486656d6686.bindPopup(popup_05fdbfd1e4d9d556a6865c4bace0141e)
#         ;

# %% [markdown]
# ### Task 5. b) Create a subset of all buildings in the municipality of Wädenswil and plot the buildings on a map.

# %%
# Subset
df_sub = df_merged.loc[df['municipalityName'] == 'Wädenswil'].sample(100).dropna()

# Create the map
m = folium.Map(location=[df_sub['latitude'].mean(), df_sub['longitude'].mean()], zoom_start=15)

# Add points to the map
for idx, row in df_sub.iterrows():
    folium.Marker(location=([row['latitude'], 
                            row['longitude']]),
                  popup=row['buildingClassDesc']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4182fdc22bdd2fc09e3732215fd3fcc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4182fdc22bdd2fc09e3732215fd3fcc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4182fdc22bdd2fc09e3732215fd3fcc = L.map(
#                 &quot;map_d4182fdc22bdd2fc09e3732215fd3fcc&quot;,
#                 {
#                     center: [47.22102017583395, 8.66017091427827],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a5907ff308682dfdae2f3562fdb9c57 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4a5907ff308682dfdae2f3562fdb9c57.addTo(map_d4182fdc22bdd2fc09e3732215fd3fcc);
#
#
#             var marker_01d24d50d7d837b26e7fe12f6849031a = L.marker(
#                 [47.21375157603386, 8.680649972926137],
#                 {}
#             ).addTo(map_d4182fdc22bdd2fc09e3732215fd3fcc);
#
#
#         var popup_e9dcf05b3cc8b504ceaebc77d3d13412 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_696ffdb2abe0fb50b2b032c557115613 = $(`&lt;div id=&quot;html_696ffdb2abe0fb50b2b032c557115613&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Landwirtschaftliche Betriebsgebäude&lt;/div&gt;`)[0];
#                 popup_e9dcf05b3cc8b504ceaebc77d3d13412.setContent(html_696ffdb2abe0fb50b2b032c557115613);
#
#
#
#         marker_01d24d50d7d837b26e7fe12f6849031a.bindPopup(popup_e9dcf05b3cc8b504ceaebc77d3d13412)
#         ;
#
#
#
#
#             var marker_1d1e2049db54d5d6d5e25db06057ea45 = L.marker(
#                 [47.19915906748069, 8.650971507915182],
#                 {}
#             ).addTo(map_d4182fdc22bdd2fc09e3732215fd3fcc);
#
#
#         var popup_a908ebeb0eafb15178d1cb1dfb03f23d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a57d16e720d572895a00961b6af530ac = $(`&lt;div id=&quot;html_a57d16e720d572895a00961b6af530ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gebäude mit einer Wohnung&lt;/div&gt;`)[0];
#                 popup_a908ebeb0eafb15178d1cb1dfb03f23d.setContent(html_a57d16e720d572895a00961b6af530ac);
#
#
#
#         marker_1d1e2049db54d5d6d5e25db06057ea45.bindPopup(popup_a908ebeb0eafb15178d1cb1dfb03f23d)
#         ;
#
#
#
#
#             var marker_e7b135b66c2aaaf7f59d9ecb2f576b72 = L.marker(
#                 [47.17618800246992, 8.668485023063953],
#                 {}
#             ).addTo(map_d4182fdc22bdd2fc09e3732215fd3fcc);
#
#
#         var popup_9541702d9d93c5fabf5256d2fb22d2aa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_99230cf7453f5d4a5d13ac34961a48e6 = $(`&lt;div id=&quot;html_99230cf7453f5d4a5d13ac34961a48e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gebäude mit zwei Wohnungen&lt;/div&gt;`)[0];
#                 popup_9541702d9d93c5fabf5256d2fb22d2aa.setContent(html_99230cf7453f5d4a5d13ac34961a48e6);
#
#
#
#         marker_e7b135b66c2aaaf7f59d9ecb2f576b72.bindPopup(popup_9541702d9d93c5fabf5256d2fb22d2aa)
#         ;
#
#
#
#
#             var marker_8a08d40484044f4a4805ffae5bc4c688 = L.marker(
#                 [47.230543073755925, 8.668531032189595],
#                 {}
#             ).addTo(map_d4182fdc22bdd2fc09e3732215fd3fcc);
#
#
#         var popup_cd8bd3c02cb3bbf54053a59d2ff18765 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d5f19e1833246941f8402e494aa1767 = $(`&lt;div id=&quot;html_2d5f19e1833246941f8402e494aa1767&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gebäude mit drei oder mehr Wohnungen&lt;/div&gt;`)[0];
#                 popup_cd8bd3c02cb3bbf54053a59d2ff18765.setContent(html_2d5f19e1833246941f8402e494aa1767);
#
#
#
#         marker_8a08d40484044f4a4805ffae5bc4c688.bindPopup(popup_cd8bd3c02cb3bbf54053a59d2ff18765)
#         ;
#
#
#
#
#             var marker_78c51a5f00314bd5e694b2e7042977db = L.marker(
#                 [47.2212703853843, 8.66081958111193],
#                 {}
#             ).addTo(map_d4182fdc22bdd2fc09e3732215fd3fcc);
#
#
#         var popup_8183e12f13b9180eb09624d8a1524e06 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_871267ab1547d8393f7d0510ec732cf4 = $(`&lt;div id=&quot;html_871267ab1547d8393f7d0510ec732cf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sonstige Hochbauten anderweitig nicht genannt&lt;/div&gt;`)[0];
#                 popup_8183e12f13b9180eb09624d8a1524e06.setContent(html_871267ab1547d8393f7d0510ec732cf4);
#
#
#
#         marker_78c51a5f00314bd5e694b2e7042977db.bindPopup(popup_8183e12f13b9180eb09624d8a1524e06)
#         ;

# %% [markdown]
# ### Task 5. c) Select and count the number of existing buildings with one apartment (GKLAS 1110) in the city of Zürich.

# %%
# Filter the DataFrame for buildings in Zürich with buildingClass 1110
zurich_buildings_one_apartment = df_merged[(df_merged['municipalityName'] == 'Zürich') & (df_merged['buildingClass'] == 1110)]

# Count the number of such buildings
count_zurich_buildings_one_apartment = zurich_buildings_one_apartment.shape[0]

print(f"Number of existing buildings with one apartment in the city of Zürich: {count_zurich_buildings_one_apartment}")
# Out:
# Number of existing buildings with one apartment in the city of Zürich: 11071

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.5.0-1025-azure
# Datetime: 2024-11-29 11:08:56
# Python Version: 3.11.10
# -----------------------------------
